# %% [markdown]
# # Install Tor

# %%
# !brew install tor
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# acl2                       gradle-profiler            nfpm
# act                        graphql-cli                ngs
# airshare                   gravity                    nicotine-plus
# alsa-lib                   grpcui                     notmuch-mutt
# amp                        gulp-cli                   numcpp
# apidoc                     halide                     oci-cli
# arb                        hashlink                   omake
# argo                       hasura-cli                 openfst
# argocd                     heksa                      openjdk@8
# arrayfire                  httpx                      oq
# arturo                     hy                         or-tools
# asimov                     i686-elf-binutils          ormolu
# asroute                    i686-elf-gcc               ory-hydra
# asuka                      idris2                     osi
# ...

# %% [markdown]
# # Load Libraries

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Scrapping Immo

# %%
# !python scraping_immo.py 1
# Out:
# Scrapped https://www.stephaneplazaimmobilier.com/agencies/search?page=1&location= with Ip Address 179.43.160.236
# Stéphane Plaza Immobilier Agen
# Scrapped https://www.stephaneplazaimmobilier.com/agences-immobilieres/281140/stephane-plaza-immobilier-agen with Ip Address 109.70.100.52
# Scrapped https://www.stephaneplazaimmobilier.com/search/all?target=all&agency_id=481&sort=&markers=true&limit=100000&page=0 with Ip Address 185.220.101.203
# Stéphane Plaza Immobilier Aigues Mortes
# Scrapped https://www.stephaneplazaimmobilier.com/agences-immobilieres/121093/stephane-plaza-immobilier-aigues-mortes with Ip Address 51.195.149.139
# Scrapped https://www.stephaneplazaimmobilier.com/search/all?target=all&agency_id=81&sort=&markers=true&limit=100000&page=0 with Ip Address 46.165.245.154
# Stéphane Plaza Immobilier Aix en Provence
# Scrapped https://www.stephaneplazaimmobilier.com/agences-immobilieres/115003/stephane-plaza-immobilier-aix-en-provence with Ip Address 185.220.101.142
# ...
